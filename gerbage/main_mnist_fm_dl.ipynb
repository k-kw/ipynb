# %%
import keras
from sklearn.datasets import fetch_openml
import torch
import torch.nn as nn
import torch.nn.functional as F
torch.manual_seed(0)
from torch.autograd import Variable
from torchsummary import summary
import torch.optim as optim
import time
import matplotlib
from torch.utils.data import DataLoader
import torch.utils.data as data
import numpy as np
import pandas as pd
import Deep_learning_torch_func as DL
#import simdat_read_func as simr
from torchvision.datasets import ImageFolder
from torchvision import transforms

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fashion_mnist = fetch_openml('Fashion-MNIST')
mnist = fetch_openml('mnist_784')
xf,yf=fashion_mnist['data'],fashion_mnist['target']
xm,ym=mnist['data'],mnist['target']

# %%
print(type(xf),type(yf),type(xm),type(ym))
print(xf.shape,yf.shape,xm.shape,ym.shape)
print(type(xf[0][0]))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (70000, 784) (70000,) (70000, 784) (70000,)
# <class 'numpy.float64'>

# %%
xf=xf.reshape(70000,1,28,28)
xm=xm.reshape(70000,1,28,28)

# %%
yf=yf.astype(int)
ym=ym.astype(int)

# %%
xf = torch.tensor(xf,dtype=torch.float32)
yf = torch.tensor(yf, dtype=torch.int64)
xm = torch.tensor(xm,dtype=torch.float32)
ym = torch.tensor(ym, dtype=torch.int64)

# %%
xf_t,xf_v=xf[:60000],xf[60000:]
xm_t,xm_v=xm[:60000],xm[60000:]
yf_t,yf_v=yf[:60000],yf[60000:]
ym_t,ym_v=ym[:60000],ym[60000:]

# %%
print(xf_t.shape)
# Out:
# torch.Size([60000, 1, 28, 28])

# %%
m_t = torch.utils.data.TensorDataset(xm_t, ym_t)
m_v = torch.utils.data.TensorDataset(xm_v, ym_v)
fm_t = torch.utils.data.TensorDataset(xf_t, yf_t)
fm_v = torch.utils.data.TensorDataset(xf_v, yf_v)

# %%
batch=64
m_l_t=DataLoader(m_t,batch_size=batch,shuffle=True)
m_l_v=DataLoader(m_v,batch_size=batch,shuffle=True)
fm_l_t=DataLoader(fm_t,batch_size=batch,shuffle=True)
fm_l_v=DataLoader(fm_v,batch_size=batch,shuffle=True)

# %%
batch=128
m_l_t=DataLoader(m_t,batch_size=batch,shuffle=True)
m_l_v=DataLoader(m_v,batch_size=batch,shuffle=True)
fm_l_t=DataLoader(fm_t,batch_size=batch,shuffle=True)
fm_l_v=DataLoader(fm_v,batch_size=batch,shuffle=True)

# %%
label_classes=10
class mnist_net(nn.Module):
    def __init__(self):
        super().__init__()
        self.CNN1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=4),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2))
        self.CNN2 = nn.Sequential(
            nn.Conv2d(32, 16, kernel_size=4),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2))
        # self.CNN3 = nn.Sequential(
        #     nn.Conv2d(64, 32, kernel_size=3),
        #     nn.BatchNorm2d(32),
        #     nn.ReLU(),
        #     nn.MaxPool2d(2))
        # self.CNN4 = nn.Sequential(
        #     nn.Conv2d(32, 16, kernel_size=3),
        #     nn.BatchNorm2d(16),
        #     nn.ReLU(),
        #     nn.MaxPool2d(2))
        self.dropout = nn.Dropout(0.1)
        self.l1 = nn.Linear(58 * 58 * 64, 1024)
        self.l2 = nn.Linear(2048, 1024)
        self.l3 = nn.Linear(1024, 512)
        self.l4 = nn.Linear(512, 128)
        self.l5 = nn.Linear(16*4*4, 128)
        self.l6 = nn.Linear(128,64)
        self.l7 = nn.Linear(64,32)
        self.fc = nn.Linear(32, label_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.CNN1(x)
        x = self.CNN2(x)
        # x = self.CNN3(x)
        # x = self.CNN4(x)
        x = x.view(x.size(0), -1)
        x = self.l5(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.l6(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.l7(x)
        x = self.relu(x)
        x = self.fc(x)
        return x

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

modellist=[]
optimizerlist=[]
criterion = nn.CrossEntropyLoss()
for i in range(2):
  modeltmp=mnist_net()
  modeltmp=modeltmp.to(device)
  summary(modeltmp,input_size=(1,28,28))
  optimizertmp = optim.SGD(modeltmp.parameters(), lr=0.01)
  modellist.append(modeltmp)
  optimizerlist.append(optimizertmp)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 25, 25]             544
#        BatchNorm2d-2           [-1, 32, 25, 25]              64
#               ReLU-3           [-1, 32, 25, 25]               0
#          MaxPool2d-4           [-1, 32, 12, 12]               0
#             Conv2d-5             [-1, 16, 9, 9]           8,208
#        BatchNorm2d-6             [-1, 16, 9, 9]              32
#               ReLU-7             [-1, 16, 9, 9]               0
#          MaxPool2d-8             [-1, 16, 4, 4]               0
#             Linear-9                  [-1, 128]          32,896
#              ReLU-10                  [-1, 128]               0
#           Dropout-11                  [-1, 128]               0
#            Linear-12                   [-1, 64]           8,256
#              ReLU-13                   [-1, 64]               0
#           Dropout-14                   [-1, 64]               0
#            Linear-15                   [-1, 32]           2,080
#              ReLU-16                   [-1, 32]               0
#            Linear-17                   [-1, 10]             330
# ================================================================
# Total params: 52,410
# Trainable params: 52,410
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.53
# Params size (MB): 0.20
# Estimated Total Size (MB): 0.73
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 25, 25]             544
#        BatchNorm2d-2           [-1, 32, 25, 25]              64
#               ReLU-3           [-1, 32, 25, 25]               0
#          MaxPool2d-4           [-1, 32, 12, 12]               0
#             Conv2d-5             [-1, 16, 9, 9]           8,208
#        BatchNorm2d-6             [-1, 16, 9, 9]              32
#               ReLU-7             [-1, 16, 9, 9]               0
#          MaxPool2d-8             [-1, 16, 4, 4]               0
#             Linear-9                  [-1, 128]          32,896
#              ReLU-10                  [-1, 128]               0
#           Dropout-11                  [-1, 128]               0
#            Linear-12                   [-1, 64]           8,256
#              ReLU-13                   [-1, 64]               0
#           Dropout-14                   [-1, 64]               0
#            Linear-15                   [-1, 32]           2,080
#              ReLU-16                   [-1, 32]               0
#            Linear-17                   [-1, 10]             330
# ================================================================
# Total params: 52,410
# Trainable params: 52,410
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.53
# Params size (MB): 0.20
# Estimated Total Size (MB): 0.73
# ----------------------------------------------------------------

# %% [markdown]
# batch128 lr0.01

# %%
DL.train_model(m_l_t,m_l_v,modellist[0],criterion,optimizerlist[0],50,device)
DL.train_model(fm_l_t,fm_l_v,modellist[1],criterion,optimizerlist[1],50,device)
md_path='./drive/MyDrive/model_param/mnist/mnist_28_e50_128_0.05.pth'
torch.save(modellist[0].state_dict(), md_path)
md_path='./drive/MyDrive/model_param/fm/fm_28_e50_128_0.05.pth'
torch.save(modellist[1].state_dict(), md_path)
# Out:
# エポック1 ,val_acc0.678 ,train_acc0.6830833333333334
# epochtime:0.12204039096832275分
# エポック2 ,val_acc0.942 ,train_acc0.9378333333333333
# epochtime:0.1203458070755005分
# エポック3 ,val_acc0.9674 ,train_acc0.9628833333333333
# epochtime:0.12095754941304525分
# エポック4 ,val_acc0.9738 ,train_acc0.9719166666666667
# epochtime:0.11888210773468018分
# エポック5 ,val_acc0.9753 ,train_acc0.9758333333333333
# epochtime:0.1197076161702474分
# エポック6 ,val_acc0.9775 ,train_acc0.9792
# epochtime:0.11651942729949952分
# エポック7 ,val_acc0.9798 ,train_acc0.9820833333333333
# epochtime:0.1171309471130371分
# エポック8 ,val_acc0.9819 ,train_acc0.9843
# epochtime:0.11793580849965414分
# エポック9 ,val_acc0.981 ,train_acc0.9834333333333334
# epochtime:0.11639546553293864分
# エポック10 ,val_acc0.983 ,train_acc0.9867833333333333
# epochtime:0.11631629864374797分
# エポック11 ,val_acc0.9849 ,train_acc0.9881166666666666
# epochtime:0.11708264748255412分
# エポック12 ,val_acc0.9851 ,train_acc0.9888333333333333
# epochtime:0.11817610263824463分
# エポック13 ,val_acc0.9854 ,train_acc0.98995
# epochtime:0.11831722259521485分
# エポック14 ,val_acc0.9851 ,train_acc0.9884333333333334
# epochtime:0.11769477526346843分
# エポック15 ,val_acc0.9853 ,train_acc0.9896166666666667
# epochtime:0.12018482287724813分
# エポック16 ,val_acc0.9849 ,train_acc0.9907166666666667
# epochtime:0.11742968161900838分
# エポック17 ,val_acc0.9851 ,train_acc0.9920166666666667
# epochtime:0.11568334897359213分
# エポック18 ,val_acc0.9866 ,train_acc0.9926166666666667
# epochtime:0.11621071894963582分
# エポック19 ,val_acc0.9878 ,train_acc0.9928
# epochtime:0.11640726725260417分
# エポック20 ,val_acc0.9852 ,train_acc0.9916166666666667
# epochtime:0.1169476866722107分
# エポック21 ,val_acc0.9864 ,train_acc0.99235
# epochtime:0.11678020556767782分
# エポック22 ,val_acc0.986 ,train_acc0.9933333333333333
# epochtime:0.1157779852549235分
# エポック23 ,val_acc0.9871 ,train_acc0.99395
# epochtime:0.1154781460762024分
# エポック24 ,val_acc0.9878 ,train_acc0.9945666666666667
# epochtime:0.11581620375315348分
# エポック25 ,val_acc0.9877 ,train_acc0.9947
# epochtime:0.116549285252889分
# エポック26 ,val_acc0.9873 ,train_acc0.9940333333333333
# epochtime:0.11522663831710815分
# エポック27 ,val_acc0.9873 ,train_acc0.9953
# epochtime:0.11600891749064128分
# エポック28 ,val_acc0.9879 ,train_acc0.9947166666666667
# epochtime:0.11457332770029703分
# エポック29 ,val_acc0.9857 ,train_acc0.99485
# epochtime:0.1160213549931844分
# エポック30 ,val_acc0.9876 ,train_acc0.9959166666666667
# epochtime:0.11484254201253255分
# エポック31 ,val_acc0.9877 ,train_acc0.9953166666666666
# epochtime:0.11464837392171225分
# エポック32 ,val_acc0.988 ,train_acc0.9964666666666666
# epochtime:0.11460100412368775分
# エポック33 ,val_acc0.9889 ,train_acc0.9969
# epochtime:0.11459728479385375分
# エポック34 ,val_acc0.987 ,train_acc0.9965
# epochtime:0.11636643409729004分
# エポック35 ,val_acc0.9889 ,train_acc0.9968833333333333
# epochtime:0.11552280187606812分
# エポック36 ,val_acc0.9888 ,train_acc0.99735
# epochtime:0.11393835544586181分
# エポック37 ,val_acc0.9893 ,train_acc0.9974166666666666
# epochtime:0.11588437954584757分
# エポック38 ,val_acc0.9887 ,train_acc0.9976833333333334
# epochtime:0.11487130324045818分
# エポック39 ,val_acc0.9887 ,train_acc0.99735
# epochtime:0.11574608484903971分
# エポック40 ,val_acc0.9882 ,train_acc0.9980833333333333
# epochtime:0.11435006459554037分
# エポック41 ,val_acc0.9876 ,train_acc0.9974833333333334
# epochtime:0.11409903367360433分
# エポック42 ,val_acc0.9879 ,train_acc0.9969333333333333
# epochtime:0.1142868717511495分
# エポック43 ,val_acc0.9877 ,train_acc0.99755
# epochtime:0.11610813538233439分
# エポック44 ,val_acc0.9881 ,train_acc0.997
# epochtime:0.11657166878382365分
# エポック45 ,val_acc0.9883 ,train_acc0.9982666666666666
# epochtime:0.11515602270762125分
# エポック46 ,val_acc0.9864 ,train_acc0.9965833333333334
# epochtime:0.11413447459538778分
# エポック47 ,val_acc0.9882 ,train_acc0.99815
# epochtime:0.11515297094980875分
# エポック48 ,val_acc0.9894 ,train_acc0.99875
# epochtime:0.115880552927653分
# エポック49 ,val_acc0.9881 ,train_acc0.9986666666666667
# epochtime:0.1152686357498169分
# エポック50 ,val_acc0.9889 ,train_acc0.9986666666666667
# epochtime:0.11483854452768961分
# エポック1 ,val_acc0.6066 ,train_acc0.6113
# epochtime:0.11677089929580689分
# エポック2 ,val_acc0.7566 ,train_acc0.7641666666666667
# epochtime:0.11505961020787557分
# エポック3 ,val_acc0.7856 ,train_acc0.7959333333333334
# epochtime:0.11539812882741292分
# エポック4 ,val_acc0.8139 ,train_acc0.8248666666666666
# epochtime:0.11517513195673625分
# エポック5 ,val_acc0.8191 ,train_acc0.8329166666666666
# epochtime:0.11505273977915446分
# エポック6 ,val_acc0.8301 ,train_acc0.8509166666666667
# epochtime:0.11540416479110718分
# エポック7 ,val_acc0.8415 ,train_acc0.8572833333333333
# epochtime:0.11609344879786174分
# エポック8 ,val_acc0.8404 ,train_acc0.8546333333333334
# epochtime:0.11656182607014974分
# エポック9 ,val_acc0.8525 ,train_acc0.8699
# epochtime:0.11569068829218547分
# エポック10 ,val_acc0.8559 ,train_acc0.8770166666666667
# epochtime:0.11381279230117798分
# エポック11 ,val_acc0.8494 ,train_acc0.8704666666666667
# epochtime:0.11497987906138102分
# エポック12 ,val_acc0.858 ,train_acc0.8796666666666667
# epochtime:0.11499973535537719分
# エポック13 ,val_acc0.8618 ,train_acc0.8833166666666666
# epochtime:0.11562235355377197分
# エポック14 ,val_acc0.8711 ,train_acc0.8914
# epochtime:0.11527103185653687分
# エポック15 ,val_acc0.8573 ,train_acc0.8751333333333333
# epochtime:0.11444912354151408分
# エポック16 ,val_acc0.874 ,train_acc0.8975166666666666
# epochtime:0.11474645137786865分
# エポック17 ,val_acc0.8759 ,train_acc0.9020666666666667
# epochtime:0.11611618200937907分
# エポック18 ,val_acc0.8715 ,train_acc0.8986666666666666
# epochtime:0.11476056575775147分
# エポック19 ,val_acc0.87 ,train_acc0.89435
# epochtime:0.11382030646006266分
# エポック20 ,val_acc0.8747 ,train_acc0.9007333333333334
# epochtime:0.11514707406361897分
# エポック21 ,val_acc0.8784 ,train_acc0.9062666666666667
# epochtime:0.11582058668136597分
# エポック22 ,val_acc0.8785 ,train_acc0.9070333333333334
# epochtime:0.1147437294324239分
# エポック23 ,val_acc0.8834 ,train_acc0.9113166666666667
# epochtime:0.11541468302408854分
# エポック24 ,val_acc0.877 ,train_acc0.9049833333333334
# epochtime:0.11516864697138468分
# エポック25 ,val_acc0.876 ,train_acc0.9048
# epochtime:0.11368816296259562分
# エポック26 ,val_acc0.8812 ,train_acc0.9121333333333334
# epochtime:0.1141294519106547分
# エポック27 ,val_acc0.883 ,train_acc0.9135666666666666
# epochtime:0.11703273057937622分
# エポック28 ,val_acc0.8689 ,train_acc0.8990333333333334
# epochtime:0.11733265320460001分
# エポック29 ,val_acc0.8816 ,train_acc0.9161
# epochtime:0.11412889957427978分
# エポック30 ,val_acc0.8806 ,train_acc0.9135833333333333
# epochtime:0.11553730964660644分
# エポック31 ,val_acc0.8762 ,train_acc0.9097666666666666
# epochtime:0.11526089509328206分
# エポック32 ,val_acc0.8854 ,train_acc0.9184666666666667
# epochtime:0.11638303200403849分
# エポック33 ,val_acc0.8848 ,train_acc0.9188166666666666
# epochtime:0.11604252656300863分
# エポック34 ,val_acc0.8877 ,train_acc0.9229333333333334
# epochtime:0.11547025839487711分
# エポック35 ,val_acc0.8864 ,train_acc0.9214166666666667
# epochtime:0.11665480534235637分
# エポック36 ,val_acc0.8873 ,train_acc0.9257
# epochtime:0.11671765247980753分
# エポック37 ,val_acc0.8876 ,train_acc0.9274333333333333
# epochtime:0.11691249211629232分
# エポック38 ,val_acc0.8843 ,train_acc0.9211333333333334
# epochtime:0.11603068908055623分
# エポック39 ,val_acc0.8839 ,train_acc0.9203
# epochtime:0.11528041760126749分
# エポック40 ,val_acc0.8847 ,train_acc0.9221666666666667
# epochtime:0.11551763216654459分
# エポック41 ,val_acc0.8876 ,train_acc0.9282
# epochtime:0.11640293598175049分
# エポック42 ,val_acc0.8877 ,train_acc0.9260166666666667
# epochtime:0.11548146406809488分
# エポック43 ,val_acc0.8788 ,train_acc0.91565
# epochtime:0.11544217665990193分
# エポック44 ,val_acc0.8903 ,train_acc0.93105
# epochtime:0.11419672171274821分
# エポック45 ,val_acc0.8908 ,train_acc0.9332
# epochtime:0.11602250337600709分
# エポック46 ,val_acc0.8865 ,train_acc0.9298666666666666
# epochtime:0.11469488938649496分
# エポック47 ,val_acc0.89 ,train_acc0.9349166666666666
# epochtime:0.11483943462371826分
# エポック48 ,val_acc0.8853 ,train_acc0.92725
# epochtime:0.1150176485379537分
# エポック49 ,val_acc0.8916 ,train_acc0.9333
# epochtime:0.11445938348770142分
# エポック50 ,val_acc0.8884 ,train_acc0.9308166666666666
# epochtime:0.11643692255020141分

# %% [markdown]
# batch128 lr0.05

# %%
DL.train_model(m_l_t,m_l_v,modellist[0],criterion,optimizerlist[0],50,device)
DL.train_model(fm_l_t,fm_l_v,modellist[1],criterion,optimizerlist[1],50,device)
md_path='./drive/MyDrive/model_param/mnist_28_e50_128_0.05.pth'
torch.save(modellist[0].state_dict(), md_path)
md_path='./drive/MyDrive/model_param/fm_28_e50_128_0.05.pth'
torch.save(modellist[1].state_dict(), md_path)
# Out:
# エポック1 ,val_acc0.9701 ,train_acc0.9673833333333334
# epochtime:0.11784557898839315分
# エポック2 ,val_acc0.9796 ,train_acc0.9774166666666667
# epochtime:0.1151202122370402分
# エポック3 ,val_acc0.9838 ,train_acc0.9846333333333334
# epochtime:0.11393937269846598分
# エポック4 ,val_acc0.984 ,train_acc0.9849666666666667
# epochtime:0.1131549596786499分
# エポック5 ,val_acc0.9879 ,train_acc0.9908
# epochtime:0.11477575302124024分
# エポック6 ,val_acc0.9858 ,train_acc0.9889833333333333
# epochtime:0.11408663193384806分
# エポック7 ,val_acc0.9853 ,train_acc0.9905166666666667
# epochtime:0.11423848867416382分
# エポック8 ,val_acc0.9877 ,train_acc0.9922833333333333
# epochtime:0.12003153165181478分
# エポック9 ,val_acc0.9907 ,train_acc0.9936666666666667
# epochtime:0.11857314904530843分
# エポック10 ,val_acc0.9904 ,train_acc0.99465
# epochtime:0.11819432179133098分
# エポック11 ,val_acc0.9899 ,train_acc0.9938833333333333
# epochtime:0.11625314553578694分
# エポック12 ,val_acc0.9893 ,train_acc0.9954666666666667
# epochtime:0.11642698844273885分
# エポック13 ,val_acc0.9905 ,train_acc0.9957
# epochtime:0.11775830189387003分
# エポック14 ,val_acc0.9915 ,train_acc0.9972333333333333
# epochtime:0.11726003487904867分
# エポック15 ,val_acc0.9883 ,train_acc0.9950333333333333
# epochtime:0.11817146142323812分
# エポック16 ,val_acc0.9897 ,train_acc0.9972333333333333
# epochtime:0.11739393472671508分
# エポック17 ,val_acc0.9902 ,train_acc0.9965333333333334
# epochtime:0.11688253084818521分
# エポック18 ,val_acc0.9904 ,train_acc0.9975166666666667
# epochtime:0.11519240935643514分
# エポック19 ,val_acc0.9903 ,train_acc0.9975166666666667
# epochtime:0.11478846867879232分
# エポック20 ,val_acc0.9914 ,train_acc0.9984
# epochtime:0.1150987943013509分
# エポック21 ,val_acc0.9925 ,train_acc0.9983
# epochtime:0.11664382219314576分
# エポック22 ,val_acc0.9914 ,train_acc0.9983833333333333
# epochtime:0.11526306867599487分
# エポック23 ,val_acc0.9918 ,train_acc0.9993333333333333
# epochtime:0.1168767253557841分
# エポック24 ,val_acc0.9909 ,train_acc0.99865
# epochtime:0.11654707590738932分
# エポック25 ,val_acc0.9911 ,train_acc0.9988
# epochtime:0.11596113840738932分
# エポック26 ,val_acc0.9917 ,train_acc0.9992166666666666
# epochtime:0.11588852802912394分
# エポック27 ,val_acc0.99 ,train_acc0.9981833333333333
# epochtime:0.11593051751454671分
# エポック28 ,val_acc0.9914 ,train_acc0.99925
# epochtime:0.11594641208648682分
# エポック29 ,val_acc0.9923 ,train_acc0.9995833333333334
# epochtime:0.11565039157867432分
# エポック30 ,val_acc0.9919 ,train_acc0.9996833333333334
# epochtime:0.1158866047859192分
# エポック31 ,val_acc0.9897 ,train_acc0.9983833333333333
# epochtime:0.11471015214920044分
# エポック32 ,val_acc0.992 ,train_acc0.9995
# epochtime:0.11547184785207112分
# エポック33 ,val_acc0.9902 ,train_acc0.9988
# epochtime:0.11409066120783488分
# エポック34 ,val_acc0.991 ,train_acc0.9996
# epochtime:0.11284011602401733分
# エポック35 ,val_acc0.9907 ,train_acc0.9997333333333334
# epochtime:0.11367405652999878分
# エポック36 ,val_acc0.9915 ,train_acc0.9996166666666667
# epochtime:0.11438496510187784分
# エポック37 ,val_acc0.9914 ,train_acc0.9996
# epochtime:0.11565897464752198分
# エポック38 ,val_acc0.9913 ,train_acc0.99965
# epochtime:0.1131847620010376分
# エポック39 ,val_acc0.9918 ,train_acc0.9993833333333333
# epochtime:0.11503948370615641分
# エポック40 ,val_acc0.9908 ,train_acc0.9991833333333333
# epochtime:0.11736343701680502分
# エポック41 ,val_acc0.9927 ,train_acc0.9995166666666667
# epochtime:0.11565287113189697分
# エポック42 ,val_acc0.9913 ,train_acc0.9997166666666667
# epochtime:0.11481502850850424分
# エポック43 ,val_acc0.9916 ,train_acc0.9999166666666667
# epochtime:0.11468034982681274分
# エポック44 ,val_acc0.9901 ,train_acc0.9992166666666666
# epochtime:0.11440227031707764分
# エポック45 ,val_acc0.9912 ,train_acc0.9996333333333334
# epochtime:0.11531365315119425分
# エポック46 ,val_acc0.9921 ,train_acc0.9997166666666667
# epochtime:0.11626328229904175分
# エポック47 ,val_acc0.9895 ,train_acc0.9990166666666667
# epochtime:0.11507081190745036分
# エポック48 ,val_acc0.9919 ,train_acc0.9998333333333334
# epochtime:0.11532793045043946分
# エポック49 ,val_acc0.9909 ,train_acc0.9997
# epochtime:0.11567921638488769分
# エポック50 ,val_acc0.992 ,train_acc0.9999333333333333
# epochtime:0.11588002840677897分
# エポック1 ,val_acc0.7947 ,train_acc0.8020666666666667
# epochtime:0.1186622182528178分
# エポック2 ,val_acc0.8406 ,train_acc0.8504833333333334
# epochtime:0.11865036090215048分
# エポック3 ,val_acc0.8554 ,train_acc0.8656333333333334
# epochtime:0.11853191057840982分
# エポック4 ,val_acc0.8614 ,train_acc0.8763166666666666
# epochtime:0.11868541240692139分
# エポック5 ,val_acc0.846 ,train_acc0.8636166666666667
# epochtime:0.1166773796081543分
# エポック6 ,val_acc0.8787 ,train_acc0.8955666666666666
# epochtime:0.11649965047836304分
# エポック7 ,val_acc0.8787 ,train_acc0.89835
# epochtime:0.1165749748547872分
# エポック8 ,val_acc0.8779 ,train_acc0.9002833333333333
# epochtime:0.11669613520304362分
# エポック9 ,val_acc0.8775 ,train_acc0.9008166666666667
# epochtime:0.11573631763458252分
# エポック10 ,val_acc0.8784 ,train_acc0.9029833333333334
# epochtime:0.1152546485265096分
# エポック11 ,val_acc0.8885 ,train_acc0.9127166666666666
# epochtime:0.1147948662439982分
# エポック12 ,val_acc0.868 ,train_acc0.8923
# epochtime:0.11642303864161173分
# エポック13 ,val_acc0.8861 ,train_acc0.9158666666666667
# epochtime:0.11782840490341187分
# エポック14 ,val_acc0.8844 ,train_acc0.91305
# epochtime:0.11583263079325358分
# エポック15 ,val_acc0.8858 ,train_acc0.9172833333333333
# epochtime:0.11712297598520914分
# エポック16 ,val_acc0.8973 ,train_acc0.9292666666666667
# epochtime:0.11749462286631267分
# エポック17 ,val_acc0.8925 ,train_acc0.9234166666666667
# epochtime:0.11581480105717977分
# エポック18 ,val_acc0.8933 ,train_acc0.9295
# epochtime:0.11613061428070068分
# エポック19 ,val_acc0.8906 ,train_acc0.9253
# epochtime:0.11628764470418294分
# エポック20 ,val_acc0.897 ,train_acc0.9366
# epochtime:0.11727677583694458分
# エポック21 ,val_acc0.8952 ,train_acc0.9327166666666666
# epochtime:0.11541889111200969分
# エポック22 ,val_acc0.8745 ,train_acc0.9076833333333333
# epochtime:0.11679911613464355分
# エポック23 ,val_acc0.8997 ,train_acc0.9401666666666667
# epochtime:0.11675564448038737分
# エポック24 ,val_acc0.9013 ,train_acc0.9401333333333334
# epochtime:0.11607727607091269分
# エポック25 ,val_acc0.8848 ,train_acc0.9226
# epochtime:0.11557690302530925分
# エポック26 ,val_acc0.895 ,train_acc0.9362833333333334
# epochtime:0.11532339652379354分
# エポック27 ,val_acc0.8981 ,train_acc0.9395
# epochtime:0.11543162663777669分
# エポック28 ,val_acc0.8931 ,train_acc0.9389666666666666
# epochtime:0.11549269755681356分
# エポック29 ,val_acc0.8894 ,train_acc0.93495
# epochtime:0.11879241863886515分
# エポック30 ,val_acc0.8978 ,train_acc0.9445333333333333
# epochtime:0.1171477238337199分
# エポック31 ,val_acc0.8959 ,train_acc0.9430166666666666
# epochtime:0.11542436679204306分
# エポック32 ,val_acc0.8982 ,train_acc0.9479166666666666
# epochtime:0.115061620871226分
# エポック33 ,val_acc0.9008 ,train_acc0.9540333333333333
# epochtime:0.11694128115971883分
# エポック34 ,val_acc0.8985 ,train_acc0.94915
# epochtime:0.11577159563700358分
# エポック35 ,val_acc0.9048 ,train_acc0.9573833333333334
# epochtime:0.11747388442357382分
# エポック36 ,val_acc0.8852 ,train_acc0.9363666666666667
# epochtime:0.11690375407536825分
# エポック37 ,val_acc0.8982 ,train_acc0.95505
# epochtime:0.11559403737386068分
# エポック38 ,val_acc0.8993 ,train_acc0.9541666666666667
# epochtime:0.11696186065673828分
# エポック39 ,val_acc0.9002 ,train_acc0.96115
# epochtime:0.11731654405593872分
# エポック40 ,val_acc0.9007 ,train_acc0.9608666666666666
# epochtime:0.11736112435658773分
# エポック41 ,val_acc0.8996 ,train_acc0.9575166666666667
# epochtime:0.11641185283660889分
# エポック42 ,val_acc0.8972 ,train_acc0.9577333333333333
# epochtime:0.11644998788833619分
# エポック43 ,val_acc0.8959 ,train_acc0.9502666666666667
# epochtime:0.11701322793960571分
# エポック44 ,val_acc0.8956 ,train_acc0.9551833333333334
# epochtime:0.1171058456103007分
# エポック45 ,val_acc0.8913 ,train_acc0.9446833333333333
# epochtime:0.11576135953267415分
# エポック46 ,val_acc0.9014 ,train_acc0.9620833333333333
# epochtime:0.11644963026046753分
# エポック47 ,val_acc0.9039 ,train_acc0.9672666666666667
# epochtime:0.1143140196800232分
# エポック48 ,val_acc0.8986 ,train_acc0.9595
# epochtime:0.11570624907811483分
# エポック49 ,val_acc0.9003 ,train_acc0.96375
# epochtime:0.11554892857869466分
# エポック50 ,val_acc0.8737 ,train_acc0.9363333333333334
# epochtime:0.11520338853200277分

# %% [markdown]
# batch64 lr0.01

# %%
DL.train_model(m_l_t,m_l_v,modellist[0],criterion,optimizerlist[0],50,device)
DL.train_model(fm_l_t,fm_l_v,modellist[1],criterion,optimizerlist[1],50,device)
md_path='./drive/MyDrive/model_param/mnist_28_e50.pth'
torch.save(modellist[0].state_dict(), md_path)
md_path='./drive/MyDrive/model_param/fm_28_e50.pth'
torch.save(modellist[1].state_dict(), md_path)
# Out:
# エポック1 ,val_acc0.9173 ,train_acc0.9123833333333333
# epochtime:0.1591023564338684分
# エポック2 ,val_acc0.9676 ,train_acc0.9657166666666667
# epochtime:0.15557895501454672分
# エポック3 ,val_acc0.976 ,train_acc0.9765166666666667
# epochtime:0.15378329356511433分
# エポック4 ,val_acc0.9811 ,train_acc0.98235
# epochtime:0.15422393480936686分
# エポック5 ,val_acc0.9828 ,train_acc0.9845833333333334
# epochtime:0.15230865875879923分
# エポック6 ,val_acc0.9821 ,train_acc0.9855333333333334
# epochtime:0.1564125418663025分
# エポック7 ,val_acc0.9854 ,train_acc0.9871666666666666
# epochtime:0.15623596906661988分
# エポック8 ,val_acc0.9846 ,train_acc0.9871333333333333
# epochtime:0.15434145132700602分
# エポック9 ,val_acc0.9869 ,train_acc0.9896
# epochtime:0.15457945267359416分
# エポック10 ,val_acc0.9877 ,train_acc0.99155
# epochtime:0.15362539291381835分
# エポック11 ,val_acc0.9877 ,train_acc0.9920166666666667
# epochtime:0.15577754179636638分
# エポック12 ,val_acc0.9895 ,train_acc0.9921666666666666
# epochtime:0.15678109327952067分
# エポック13 ,val_acc0.9895 ,train_acc0.9923
# epochtime:0.1564799467722575分
# エポック14 ,val_acc0.9884 ,train_acc0.9933666666666666
# epochtime:0.15857264200846355分
# エポック15 ,val_acc0.9881 ,train_acc0.9935
# epochtime:0.15544640223185222分
# エポック16 ,val_acc0.9888 ,train_acc0.9943666666666666
# epochtime:0.15661762158075967分
# エポック17 ,val_acc0.9895 ,train_acc0.9948833333333333
# epochtime:0.15513951381047567分
# エポック18 ,val_acc0.9889 ,train_acc0.9949666666666667
# epochtime:0.157064688205719分
# エポック19 ,val_acc0.9879 ,train_acc0.9938833333333333
# epochtime:0.15948355197906494分
# エポック20 ,val_acc0.9908 ,train_acc0.9962333333333333
# epochtime:0.15837932030359905分
# エポック21 ,val_acc0.9895 ,train_acc0.9967
# epochtime:0.1597515066464742分
# エポック22 ,val_acc0.9896 ,train_acc0.9961166666666667
# epochtime:0.15780494610468546分
# エポック23 ,val_acc0.9897 ,train_acc0.9968166666666667
# epochtime:0.15985342264175414分
# エポック24 ,val_acc0.9877 ,train_acc0.9947333333333334
# epochtime:0.15743216276168823分
# エポック25 ,val_acc0.9905 ,train_acc0.9976
# epochtime:0.15657719373703002分
# エポック26 ,val_acc0.9908 ,train_acc0.99715
# epochtime:0.16004414558410646分
# エポック27 ,val_acc0.9902 ,train_acc0.9975333333333334
# epochtime:0.15922366778055827分
# エポック28 ,val_acc0.9877 ,train_acc0.9951333333333333
# epochtime:0.15651495059331258分
# エポック29 ,val_acc0.9906 ,train_acc0.9978833333333333
# epochtime:0.15791870752970377分
# エポック30 ,val_acc0.9886 ,train_acc0.99575
# epochtime:0.15781493584314982分
# エポック31 ,val_acc0.9906 ,train_acc0.9985666666666667
# epochtime:0.15746035973230998分
# エポック32 ,val_acc0.9897 ,train_acc0.9984333333333333
# epochtime:0.15642571449279785分
# エポック33 ,val_acc0.9903 ,train_acc0.99815
# epochtime:0.15640875101089477分
# エポック34 ,val_acc0.9903 ,train_acc0.9987166666666667
# epochtime:0.15753300587336222分
# エポック35 ,val_acc0.9907 ,train_acc0.99905
# epochtime:0.15634092489878337分
# エポック36 ,val_acc0.9899 ,train_acc0.9987333333333334
# epochtime:0.15643924474716187分
# エポック37 ,val_acc0.9895 ,train_acc0.9985833333333334
# epochtime:0.15761455297470092分
# エポック38 ,val_acc0.9908 ,train_acc0.9991
# epochtime:0.15757436752319337分
# エポック39 ,val_acc0.9908 ,train_acc0.9992
# epochtime:0.15731946229934693分
# エポック40 ,val_acc0.9884 ,train_acc0.9984333333333333
# epochtime:0.15651806990305583分
# エポック41 ,val_acc0.9906 ,train_acc0.99945
# epochtime:0.1571372151374817分
# エポック42 ,val_acc0.9907 ,train_acc0.99905
# epochtime:0.1564568042755127分
# エポック43 ,val_acc0.9899 ,train_acc0.9994666666666666
# epochtime:0.15671634674072266分
# エポック44 ,val_acc0.9906 ,train_acc0.9995333333333334
# epochtime:0.15708967844645183分
# エポック45 ,val_acc0.9898 ,train_acc0.9994166666666666
# epochtime:0.15556609630584717分
# エポック46 ,val_acc0.9899 ,train_acc0.9992333333333333
# epochtime:0.1587684671084086分
# エポック47 ,val_acc0.99 ,train_acc0.9996
# epochtime:0.15632288058598837分
# エポック48 ,val_acc0.9905 ,train_acc0.99955
# epochtime:0.15608654816945394分
# エポック49 ,val_acc0.9903 ,train_acc0.9989166666666667
# epochtime:0.15480972528457643分
# エポック50 ,val_acc0.991 ,train_acc0.9996
# epochtime:0.15451550483703613分
# エポック1 ,val_acc0.7426 ,train_acc0.7459833333333333
# epochtime:0.15778772433598837分
# エポック2 ,val_acc0.8077 ,train_acc0.8114333333333333
# epochtime:0.1572439710299174分
# エポック3 ,val_acc0.8307 ,train_acc0.8416166666666667
# epochtime:0.15739914178848266分
# エポック4 ,val_acc0.8387 ,train_acc0.8485166666666667
# epochtime:0.15713906288146973分
# エポック5 ,val_acc0.858 ,train_acc0.8734833333333333
# epochtime:0.15696741342544557分
# エポック6 ,val_acc0.8507 ,train_acc0.8686333333333334
# epochtime:0.1578305681546529分
# エポック7 ,val_acc0.8582 ,train_acc0.8735666666666667
# epochtime:0.15880768696467082分
# エポック8 ,val_acc0.8656 ,train_acc0.8854833333333333
# epochtime:0.15762286980946857分
# エポック9 ,val_acc0.8692 ,train_acc0.8861
# epochtime:0.15898882150650023分
# エポック10 ,val_acc0.8665 ,train_acc0.8878166666666667
# epochtime:0.1567511796951294分
# エポック11 ,val_acc0.868 ,train_acc0.88845
# epochtime:0.1589604616165161分
# エポック12 ,val_acc0.858 ,train_acc0.88085
# epochtime:0.1590619444847107分
# エポック13 ,val_acc0.8781 ,train_acc0.9038166666666667
# epochtime:0.15771505037943523分
# エポック14 ,val_acc0.8854 ,train_acc0.9118
# epochtime:0.15871832768122354分
# エポック15 ,val_acc0.8788 ,train_acc0.9025
# epochtime:0.15842089255650837分
# エポック16 ,val_acc0.8771 ,train_acc0.90515
# epochtime:0.1614170749982198分
# エポック17 ,val_acc0.8925 ,train_acc0.9188
# epochtime:0.15728087822596232分
# エポック18 ,val_acc0.8871 ,train_acc0.91325
# epochtime:0.16028422514597576分
# エポック19 ,val_acc0.8901 ,train_acc0.919
# epochtime:0.1615284244219462分
# エポック20 ,val_acc0.8862 ,train_acc0.9180333333333334
# epochtime:0.15606215397516887分
# エポック21 ,val_acc0.8836 ,train_acc0.9129
# epochtime:0.15756060679753622分
# エポック22 ,val_acc0.8836 ,train_acc0.9107
# epochtime:0.1567792336146037分
# エポック23 ,val_acc0.8813 ,train_acc0.9135
# epochtime:0.15492406288782756分
# エポック24 ,val_acc0.8815 ,train_acc0.9133166666666667
# epochtime:0.1532620628674825分
# エポック25 ,val_acc0.8766 ,train_acc0.9071333333333333
# epochtime:0.15261029799779255分
# エポック26 ,val_acc0.8623 ,train_acc0.8942166666666667
# epochtime:0.1564743677775065分
# エポック27 ,val_acc0.8881 ,train_acc0.9229666666666667
# epochtime:0.15524545113245647分
# エポック28 ,val_acc0.8915 ,train_acc0.9298833333333333
# epochtime:0.1542642633120219分
# エポック29 ,val_acc0.8944 ,train_acc0.93375
# epochtime:0.1549132506052653分
# エポック30 ,val_acc0.884 ,train_acc0.9222333333333333
# epochtime:0.15473647514979044分
# エポック31 ,val_acc0.8908 ,train_acc0.9328333333333333
# epochtime:0.15541218916575114分
# エポック32 ,val_acc0.8895 ,train_acc0.9307
# epochtime:0.15501017570495607分
# エポック33 ,val_acc0.8942 ,train_acc0.9401333333333334
# epochtime:0.15381367603937784分
# エポック34 ,val_acc0.8957 ,train_acc0.938
# epochtime:0.15522226492563884分
# エポック35 ,val_acc0.895 ,train_acc0.9387666666666666
# epochtime:0.15397963921229044分
# エポック36 ,val_acc0.8915 ,train_acc0.9378666666666666
# epochtime:0.1559090256690979分
# エポック37 ,val_acc0.8864 ,train_acc0.93285
# epochtime:0.15476409991582235分
# エポック38 ,val_acc0.8898 ,train_acc0.9326166666666666
# epochtime:0.15556693077087402分
# エポック39 ,val_acc0.8942 ,train_acc0.94405
# epochtime:0.1545068383216858分
# エポック40 ,val_acc0.8982 ,train_acc0.9466
# epochtime:0.155036195119222分
# エポック41 ,val_acc0.891 ,train_acc0.9407666666666666
# epochtime:0.15566445191701253分
# エポック42 ,val_acc0.89 ,train_acc0.93865
# epochtime:0.15582356452941895分
# エポック43 ,val_acc0.8927 ,train_acc0.94355
# epochtime:0.1551801045735677分
# エポック44 ,val_acc0.8882 ,train_acc0.9393166666666667
# epochtime:0.15572696129480998分
# エポック45 ,val_acc0.8903 ,train_acc0.93765
# epochtime:0.1550455927848816分
# エポック46 ,val_acc0.8912 ,train_acc0.94125
# epochtime:0.15627832810084025分
# エポック47 ,val_acc0.8933 ,train_acc0.9493
# epochtime:0.15534783999125162分
# エポック48 ,val_acc0.8877 ,train_acc0.9416833333333333
# epochtime:0.15476313829421998分
# エポック49 ,val_acc0.894 ,train_acc0.9526
# epochtime:0.154820974667867分
# エポック50 ,val_acc0.8954 ,train_acc0.9556
# epochtime:0.15470033486684162分
